# %% [markdown]
# <a href="https://colab.research.google.com/github/adhirajgupta/Wharton-Data-Science-/blob/main/Wharton_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# %%
#to import the files from my computer
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f8fb1bed-7ade-4010-b2d6-3e1343115ad8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f8fb1bed-7ade-4010-b2d6-3e1343115ad8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import sklearn
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.metrics import accuracy_score

# %%
#reg_season = pd.read_csv("NSL_Regular_Season_Data.csv")
grp_round = pd.read_csv("NSL_Group_Round_Games.csv")
metadata = pd.read_csv("NSL_Metadata.csv")
knockout = pd.read_csv("NSL_Knockout_Round_Games.csv")

reg_custom = pd.read_csv("regular_season_data_2.csv")
eastern = pd.read_csv("Group Round Eastern.csv")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-08fd152596df> in <cell line: 2>()
#       1 #reg_season = pd.read_csv("NSL_Regular_Season_Data.csv")
# ----> 2 grp_round = pd.read_csv("NSL_Group_Round_Games.csv")
#       3 metadata = pd.read_csv("NSL_Metadata.csv")
#       4 knockout = pd.read_csv("NSL_Knockout_Round_Games.csv")
#       5
#
# TypeError: 'str' object is not callable

# %%
reg_season.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 509 entries, 0 to 508
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   n              476 non-null    float64
#  1   game_id        476 non-null    object
#  2   HomeTeam       476 non-null    object
#  3   AwayTeam       476 non-null    object
#  4   HomeScore      476 non-null    float64
#  5   AwayScore      476 non-null    float64
#  6   Home_xG        476 non-null    float64
#  7   Away_xG        476 non-null    float64
#  8   Home_shots     476 non-null    float64
#  9   Away_shots     476 non-null    float64
#  10  Home_corner    476 non-null    float64
#  11  Away_corner    476 non-null    float64
#  12  Home_PK_Goal   476 non-null    float64
#  13  Away_PK_Goal   476 non-null    float64
#  14  Home_PK_shots  476 non-null    float64
#  15  Away_PK_shots  476 non-null    float64
#  16  Home_ToP       476 non-null    float64
# ...

# %%
knockout.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   game_id  6 non-null      object
#  1   TeamA    6 non-null      object
#  2   TeamB    6 non-null      object
# dtypes: object(3)
# memory usage: 272.0+ bytes

# %%
reg_season.head(20)
# Out:
#        n       game_id HomeTeam AwayTeam  HomeScore  AwayScore  Home_xG  \
# 0    1.0   game_2023_1      PRO      MAN        1.0        1.0     1.63
# 1    2.0   game_2023_2      FOR      LEX        1.0        0.0     0.98
# 2    3.0   game_2023_3      SJU      DES        1.0        2.0     1.23
# 3    4.0   game_2023_4      FAR      ANC        0.0        1.0     2.27
# 4    5.0   game_2023_5      DOV      BAK        0.0        0.0     1.90
# 5    6.0   game_2023_6      ALB      LAR        1.0        1.0     0.62
# 6    7.0   game_2023_7      SAS      MOB        0.0        0.0     0.75
# 7    8.0   game_2023_8      CHM      EUG        0.0        0.0     1.54
# 8    9.0   game_2023_9      TOL      JAC        1.0        2.0     1.20
# 9   10.0  game_2023_10      REN      OAK        1.0        1.0     0.70
# 10  11.0  game_2023_11      SFS      AUG        1.0        1.0     1.34
# 11  12.0  game_2023_12      TUC      BOI        1.0        5.0     1.06
# ...

# %%
X =
